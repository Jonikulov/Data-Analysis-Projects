# %% [markdown]
# <details><summary><b>Data Analysis Projects</b></summary>
#
# - **Google**
#     - 💡[Project Ideas]https://datacamp.com/blog/data-analytics-projects-all-levels
#     - https://coursera.org/articles/data-analytics-projects-for-beginners
#     - https://interviewbit.com/blog/data-analytics-projects/
#     - https://dataquest.io/blog/free-datasets-for-projects/
#     - https://projectpro.io/article/big-data-analytics-projects-for-students-/436
#     - https://projectpro.io/article/15-data-science-projects-for-beginners-with-source-code/343
#     - https://springboard.com/blog/data-analytics/data-analysis-projects/
#     - https://dataquest.io/blog/data-analyst-projects-for-beginners/
#     - https://careerfoundry.com/en/blog/data-analytics/data-analytics-portfolio-project-ideas/
#     - https://amankharwal.medium.com/data-analysis-projects-with-python-a262a6f9e68c
#     - https://kdnuggets.com/2023/02/5-data-analysis-projects-beginners.html
#     - https://mygreatlearning.com/academy/learn-for-free/courses/data-analysis-projects
#     - https://udemy.com/course/data-analytics-projects-python/
#     - https://ml.cmu.edu/research/data-analysis-projects.html
#
# - **YouTube**
#     - ~~https://www.youtube.com/playlist?list=PLeo1K3hjS3uuVQccZa7yFwK3ltoGQOWbM~~
#     - **https://www.youtube.com/playlist?list=PLy3lFw0OTlutzXFVwttrtaRGEEyLEdnpy**
#     - https://www.youtube.com/playlist?list=PLeo1K3hjS3utcb9nKtanhcn8jd2E0Hp9b
#     - https://www.youtube.com/playlist?list=PLUaB-1hjhk8H48Pj32z4GZgGWyylqv85f
#     - https://www.youtube.com/playlist?list=PLMfXakCUhXsEUtk8c0zWr4whamGxLhAu0
#     - https://www.youtube.com/playlist?list=PLy3lFw0OTlutpxVdO8JVT7AUvWc8Cy8eB
#     - https://youtube.com/watch?v=R67XuYc9NQ4/
# </details>
# ---
# <details><summary><b>Data Projects</b></summary>
#
# - **Google**
#     - ...
#
# - **YouTube**
#     - ...
# </details>
# ---
#
# <details><summary><b>Exploratory Data Analysis (EDA)</b></summary>
#
# - **Google**
#     - ...
#
# - **YouTube**
#     - ...
# </details>
# ---
# <details><summary><b>Investigate a Dataset</b></summary>
#
# - **Google**
#     - ...
#
# - **YouTube**
#     - ...
# </details>
# ---
# <details><summary><b>Probability & Statistics (data) Projects</b></summary>
#
# - **Google**
#     - ...
#
# - **YouTube**
#     - ...
# </details>
# ---
# <details><summary><b>Predictive (data) Analytics Projects</b></summary>
#
# - **Google**
#     - ...
#
# - **YouTube**
#     - ...
# </details>
# ---
# <details><summary><b>End-to-end Data Analytics Projects</b></summary>
# In general, you will be:
#
# 1. Dealing with multiple datasets
# 2. Understanding the data distribution
# 3. Applying data cleaning and manipulation
# 4. Applying probability and statical techniques
# 5. Performing data analysis and visualization
# 6. Using machine learning model for predictive analysis
# 7. Creating the report or dashboard
# - **Google**
#     - ...
#
# - **YouTube**
#     - ...
# </details>
#
# ---
# - **kaggle, imdb, tmdb, global data, WeForum…**
#     - ...
#
# ---

# %% [markdown]
# **Prompt:** provide me at least 15 datasets (what datasets should i work on) for Data Analysis Projects / Data Projects in order to improve my Exploratory Data Analysis and Investigating a Datase skills (only data analysis)
#
# **ChatGPT:**
# 1. Titanic Dataset - contains information about passengers on the Titanic, including demographics and survival status.
# 2. Wine Quality Dataset - contains the physicochemical properties and quality ratings of red and white wine samples.
# 3. Airbnb Dataset - contains information about Airbnb listings, including price, location, and amenities.
# 4. US Election Dataset - contains information about the results of the 2020 US Presidential election by state and county.
# 5. Google Play Store Apps Dataset - contains information about Android apps on the Google Play Store, including ratings and reviews.
# 6. New York City Taxi Dataset - contains information about taxi rides in New York City, including pickup and drop-off locations and fares.
# 7. Iris Dataset - contains measurements of iris flowers, including species and petal/sepal dimensions.
# 8. Supermarket Sales Dataset - contains information about sales transactions at a supermarket, including products sold and customer demographics.
# 9. FIFA World Cup Dataset - contains information about the results of every FIFA World Cup match, including teams, scores, and game statistics.
# 10. Customer Churn Dataset - contains information about customers who have churned from a telecommunications company, including demographics and usage patterns.
# 11. MovieLens Dataset - contains information about movie ratings and reviews from the MovieLens website.
# 12. Boston Housing Dataset - contains information about housing prices and features in Boston.
# 13. Amazon Top 50 Bestselling Books Dataset - contains information about the top 50 bestselling books on Amazon, including author, rating, and reviews.
# 14. YouTube Trending Videos Dataset - contains information about trending YouTube videos, including views, likes, and dislikes.
# 15. World Happiness Report Dataset - contains information about happiness scores and factors from the World Happiness Report.
# ---
# **Prompt:** provide me at least 15 USEFUL datasets (what datasets should i work on) for Data Analysis Projects / Data Projects in order to improve my Exploratory Data Analysis and Investigating a Datase skills (only data analysis)
#
# **ChatGPT:**
# 1. World Bank Open Data: The World Bank provides data on a wide range of economic and social indicators, such as GDP, population, and poverty rates, for countries around the world.
# 2. Kaggle Datasets: Kaggle is a platform for data scientists and machine learning engineers to find and share datasets, as well as compete in data science challenges.
# 3. FiveThirtyEight Datasets: FiveThirtyEight is a popular data journalism website that provides a wide range of datasets on topics such as politics, sports, and entertainment.
# 4. UCI Machine Learning Repository: The UCI Machine Learning Repository is a collection of datasets that can be used for various machine learning tasks, such as classification and regression.
# 5. Google Trends Data: Google Trends provides data on the popularity of search terms over time, which can be useful for understanding trends and patterns in online behavior.
# 6. Yelp Dataset: The Yelp dataset contains data on over 5 million reviews and businesses, and can be used for various data analysis tasks such as sentiment analysis and customer segmentation.
# 7. Airbnb Data: Airbnb provides data on its listings, bookings, and reviews, which can be used for various data analysis tasks related to the hospitality industry.
# 8. IMDb Dataset: The IMDb dataset contains information on movies and TV shows, including ratings, genres, and cast information, which can be used for various data analysis tasks related to the entertainment industry.
# 9. Spotify Dataset: Spotify provides data on music tracks, including features such as tempo, loudness, and danceability, which can be used for various data analysis tasks related to the music industry.
# 10. Twitter Data: Twitter provides data on its users and their tweets, which can be used for various data analysis tasks related to social media behavior and sentiment analysis.
# 11. NYC Open Data: The NYC Open Data portal provides data on a wide range of topics related to New York City, including crime, transportation, and public health.
# 12. CDC Wonder: The CDC Wonder database provides data on a wide range of health-related topics, including diseases, mortality rates, and healthcare utilization.
# 13. National Center for Education Statistics: The National Center for Education Statistics provides data on various aspects of education, such as enrollment rates, graduation rates, and test scores.
# 14. Gapminder: Gapminder provides data on various economic and social indicators for countries around the world, and can be used to analyze trends and patterns in global development.
# 15. Pew Research Center: The Pew Research Center provides data on various topics related to public opinion and social trends, such as political views, technology use, and demographic changes.
#
# ---
